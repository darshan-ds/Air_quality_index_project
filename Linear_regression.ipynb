# %% [markdown]
# ## Assigning working directory

# %%
import os
os.chdir('C:/Users/Darshan/Desktop/Air_quality_index_project')

# %% [markdown]
# ## Importing Necessary Libraries

# %%
# Libraries for Data manipulation
import numpy as np
import pandas as pd

# Libraries for Data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Library for scientific computing
from scipy.stats import norm

# Optional import for jupyter notebook users
# %matplotlib inline

# To set the style of the plots. For more styles input plt.style.available
plt.style.use('seaborn-whitegrid')

# %% [markdown]
# ## Importing Datasets

# %%
# pd.read_csv() will read a csv file from the mentioned location

df = pd.read_csv('Data/Real-Data/Real_Combine.csv')

# %%
# To know what does the columns mean in our main dataframe we import its descriptions.

df_desc = pd.read_csv('Data/Real-Data/data_description.csv', index_col='column_name')

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Basic Commands

# %%
# Returns a tuple with number of rows and number of columns respectively

df.shape
# Out:
# (2232, 9)

# %%
# To view the top 5 rows we use head() function

df.head()
# Out:
#       T    TM    Tm SLP   H   VV    V   VM   PM 2.5
# 0  23.4  30.3  19.0   -  59  6.3  4.3  5.4  284.796
# 1  23.4  30.3  19.0   -  59  6.3  4.3  5.4  284.796
# 2  23.4  30.3  19.0   -  59  6.3  4.3  5.4  284.796
# 3  22.4  30.3  16.9   -  57  6.9  3.3  7.6  219.721
# 4  22.4  30.3  16.9   -  57  6.9  3.3  7.6  219.721

# %%
# Returns information about the dataframe(Name of columns, Not-Null count, datatype and memory usage)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2232 entries, 0 to 2231
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   T       2232 non-null   float64
#  1   TM      2232 non-null   float64
#  2   Tm      2232 non-null   float64
#  3   SLP     2232 non-null   object
#  4   H       2232 non-null   int64
#  5   VV      2232 non-null   float64
#  6   V       2232 non-null   float64
#  7   VM      2232 non-null   object
#  8   PM 2.5  2229 non-null   float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 157.1+ KB

# %%
# Returns the sample statistics of all the numerical columns in the dataframe

# The .T returns the transpose of the matrix

df.describe().T
# Out:
#          count        mean        std   min   25%     50%     75%    max
# T       2232.0   24.109677   2.281077  18.9  22.6  23.700   25.30   31.2
# TM      2232.0   30.486425   2.836346  22.0  28.4  30.000   32.10   39.2
# Tm      2232.0   19.733602   2.227985  12.9  18.7  20.000   20.90   25.8
# H       2232.0   65.729839  14.616694  25.0  56.0  69.000   77.00   97.0
# VV      2232.0    6.683333   0.670363   4.0   6.3   6.900    6.90    9.2
# V       2232.0    3.833737   2.295326   0.0   2.2   3.500    5.20   12.4
# PM 2.5  2229.0  108.688474  83.282483   0.0  43.5  81.833  156.25  404.5

# %%
df.columns
# Out:
# Index(['T', 'TM', 'Tm', 'SLP', 'H', 'VV', 'V', 'VM', 'PM 2.5'], dtype='object')

# %% [markdown]
# ### Inspecting all the columns

# %% [markdown]
# #### Average Temperature (T)

# %%
# What does the column 'T' mean.

df_desc.loc['T']
# Out:
# description    Average Temperature (°C)
# Name: T, dtype: object

# %%
# What are the unique values in 'T' column.

df['T'].unique()
# Out:
# array([23.4, 22.4, 24. , 22.8, 23.1, 22.9, 22.3, 21.8, 21.6, 21.9, 22.1,
#        21.4, 24.6, 23.9, 24.5, 24.3, 24.8, 24.1, 24.7, 25.5, 25.3, 25.4,
#        25.8, 27.1, 26.8, 26.9, 28.1, 28.8, 28.5, 27.2, 27.8, 29.9, 29.4,
#        29.6, 27.7, 29.2, 27.5, 28.2, 28.9, 28.4, 28.7, 28.3, 28. , 26.1,
#        26.3, 26.4, 26.2, 25.2, 27.3, 26.5, 26.6, 23.7, 23.8, 23. , 23.6,
#        23.5, 22.6, 22.2, 23.3, 21.3, 22.5, 22. , 23.2, 22.7, 20.7, 24.2,
#        21.7, 24.9, 24.4, 21.5, 20.2, 21.2, 20.4, 20.6, 20.8, 19.9, 20.1,
#        20.3, 21. , 20.9, 25.6, 27.9, 27.6, 28.6, 25.7, 29.8, 29.3, 27.4,
#        25.9, 26. , 21.1, 20. , 19.4, 25.1, 27. , 19.3, 19.1, 26.7, 29. ,
#        30.4, 31.2, 30.7, 30.3, 30.5, 25. , 18.9])

# %%
# Number of unique values in 'T' column.

df['T'].nunique()
# Out:
# 106

# %%
# What is the total count of 'T' column.

df['T'].count()
# Out:
# 2232

# %%
# Sample statistics of the 'T' column.

df['T'].describe()
# Out:
# count    2232.000000
# mean       24.109677
# std         2.281077
# min        18.900000
# 25%        22.600000
# 50%        23.700000
# 75%        25.300000
# max        31.200000
# Name: T, dtype: float64

# %%
# Finding if there are any null values in 'T' column
# isnull() function returns a boolean dataframe and
# the sum() function will add all the True values.

df['T'].isnull().sum()
# Out:
# 0

# %%
# plotting a histogram of 'T' columns

# Here we are plotting a normal curve above the histogram to better understand the distribution of the data.

# We will import norm library
from scipy.stats import norm

# Setting the size of the plot
plt.figure(figsize=(9,7))

# Fit a normal distribution to the data:
data = df['T']
mean, std = norm.fit(data)

# Plot the histogram.
plt.hist(data, bins=25, density=True, alpha=0.6, color='g')

# Plot the PDF.
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mean, std)
plt.plot(x, p, 'k', linewidth=2)
title = "Fit results: mean = %.2f,  std = %.2f" % (mean, std)
plt.title(title)
plt.xlabel('Temperature')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
x = np.linspace(xmin, xmax, 100)

# %%
x
# Out:
# array([18.285     , 18.42166667, 18.55833333, 18.695     , 18.83166667,
#        18.96833333, 19.105     , 19.24166667, 19.37833333, 19.515     ,
#        19.65166667, 19.78833333, 19.925     , 20.06166667, 20.19833333,
#        20.335     , 20.47166667, 20.60833333, 20.745     , 20.88166667,
#        21.01833333, 21.155     , 21.29166667, 21.42833333, 21.565     ,
#        21.70166667, 21.83833333, 21.975     , 22.11166667, 22.24833333,
#        22.385     , 22.52166667, 22.65833333, 22.795     , 22.93166667,
#        23.06833333, 23.205     , 23.34166667, 23.47833333, 23.615     ,
#        23.75166667, 23.88833333, 24.025     , 24.16166667, 24.29833333,
#        24.435     , 24.57166667, 24.70833333, 24.845     , 24.98166667,
#        25.11833333, 25.255     , 25.39166667, 25.52833333, 25.665     ,
#        25.80166667, 25.93833333, 26.075     , 26.21166667, 26.34833333,
#        26.485     , 26.62166667, 26.75833333, 26.895     , 27.03166667,
# ...

# %%
# Kurtosis is a statistical measure that defines how heavily the tails of a distribution differ from the tails 
# of a normal distribution. In other words, kurtosis identifies whether the tails of a given distribution
# contain extreme values.

df['T'].kurtosis()
# Out:
# 0.04951324560112402

# %%
# In statistics, skewness is a measure of the asymmetry of the probability distribution of a random variable about its mean.
# In other words, skewness tells you the amount and direction of skew (departure from horizontal symmetry). 
# The skewness value can be positive or negative, or even undefined.

df['T'].skew()
# Out:
# 0.651268655449692

# %%
# Since the skewness and kurtosis are within 1. We can assume that the data is approximately normally distributed.

# %%
# Plotting a boxplot.
# A box plot will tell us the distribution of the data, the quantiles, and outliers if any.

plt.figure(figsize=(9,12))
sns.boxplot(y=df['T'])
plt.title('Boxplot of Average Temperature')
plt.ylabel('Average Temperature')
# Out:
# Text(0, 0.5, 'Average Temperature')

# %% [markdown]
# #### Maximum temperature (TM)

# %%
df_desc.loc['TM']
# Out:
# description    Maximum temperature (°C)
# Name: TM, dtype: object

# %%
df['TM'].unique()
# Out:
# array([30.3, 31.8, 30.2, 30.6, 30.1, 29.6, 29.9, 29.1, 29.2, 29.8, 32.2,
#        31.6, 31.5, 31.4, 33.4, 32.4, 33. , 33.2, 30.4, 32. , 34.1, 34.8,
#        34.7, 34.2, 34.6, 34.5, 35.4, 35.8, 36.5, 34.9, 36.8, 36. , 36.2,
#        35.9, 35.7, 35.3, 37. , 37.6, 35.1, 32.1, 33.8, 34. , 33.5, 31.3,
#        29.4, 27.6, 28.8, 28.4, 28.3, 28.6, 27.8, 28.5, 28.1, 28.7, 27.3,
#        27.4, 27. , 26. , 26.9, 26.2, 28. , 29.5, 25.1, 26.8, 26.7, 29. ,
#        29.7, 30.8, 27.7, 25.4, 27.5, 27.9, 28.9, 30. , 30.5, 27.2, 28.2,
#        26.4, 29.3, 32.6, 32.7, 31.1, 32.8, 33.1, 36.4, 35.5, 36.3, 35.6,
#        33.9, 35.2, 34.4, 35. , 31.2, 30.7, 31. , 33.6, 27.1, 26.6, 24.3,
#        24.6, 25.2, 31.7, 32.3, 33.3, 30.9, 24.8, 23.8, 23.9, 24.9, 25.9,
#        31.9, 32.5, 34.3, 37.2, 37.4, 36.6, 39.2, 37.1, 37.3, 33.7, 26.5,
#        25.8, 25. , 22. ])

# %%
df['TM'].nunique()
# Out:
# 124

# %%
df['TM'].count()
# Out:
# 2232

# %%
df['TM'].describe()
# Out:
# count    2232.000000
# mean       30.486425
# std         2.836346
# min        22.000000
# 25%        28.400000
# 50%        30.000000
# 75%        32.100000
# max        39.200000
# Name: TM, dtype: float64

# %%
df['TM'].isnull().sum()
# Out:
# 0

# %%
plt.figure(figsize=(9,7))

mean, std = norm.fit(df['TM'])

plt.hist(df['TM'],bins=25,color='r',alpha=0.7,density=True)


xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)

p = norm.pdf(x, mean, std)
plt.plot(x, p, 'k', linewidth=2)

plt.title('The mean is %.2f and std is %.2f '% (mean, std))
plt.xlabel('Maximum Temperature')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# Here we can see that the distribution is almost normal.

# %%
df['TM'].kurtosis()
# Out:
# -0.2398559670968945

# %%
df['TM'].skew()
# Out:
# 0.508808898793555

# %%
plt.figure(figsize=(8,12))

sns.boxplot(y=df['TM'])
plt.title('Maximum Temperature Boxplot')
plt.ylabel('Max Temperature')
# Out:
# Text(0, 0.5, 'Max Temperature')

# %% [markdown]
# #### Minimum temperature (Tm)

# %%
df.columns
# Out:
# Index(['T', 'TM', 'Tm', 'SLP', 'H', 'VV', 'V', 'VM', 'PM 2.5'], dtype='object')

# %%
df_desc.loc['Tm']
# Out:
# description    Minimum temperature (°C)
# Name: Tm, dtype: object

# %%
df.Tm.unique()
# Out:
# array([19. , 16.9, 17.6, 17.4, 15.7, 14.8, 14.2, 16.4, 16.6, 17.5, 15.5,
#        14.6, 15.6, 17.3, 15.3, 15.2, 14.4, 18.8, 21. , 18.9, 19.7, 20.2,
#        20.5, 18. , 15.9, 16.3, 18.5, 20. , 20.3, 20.7, 19.9, 20.4, 21.3,
#        23.2, 22.9, 22.4, 22.2, 22.1, 23.3, 24.4, 24.5, 21.4, 23.1, 22.6,
#        22.5, 22.7, 24. , 24.3, 23.4, 21.9, 21.6, 20.9, 22. , 20.6, 20.8,
#        19.2, 20.1, 19.4, 19.8, 19.6, 19.5, 19.1, 21.1, 18.6, 18.4, 17.8,
#        16.8, 18.2, 16.5, 16. , 14.7, 14.5, 14.9, 15. , 15.8, 17. , 15.4,
#        19.3, 17.1, 18.7, 23.5, 22.3, 21.5, 23.8, 24.7, 24.8, 24.2, 24.6,
#        22.8, 23.6, 21.2, 21.8, 17.9, 18.3, 13.9, 13.7, 16.2, 17.7, 17.2,
#        24.1, 23. , 18.1, 21.7, 16.1, 12.9, 15.1, 25.1, 25.4, 25.8, 16.7])

# %%
df.Tm.nunique()
# Out:
# 110

# %%
df.Tm.count()
# Out:
# 2232

# %%
df.Tm.isnull().sum()
# Out:
# 0

# %%
df.Tm.describe()
# Out:
# count    2232.000000
# mean       19.733602
# std         2.227985
# min        12.900000
# 25%        18.700000
# 50%        20.000000
# 75%        20.900000
# max        25.800000
# Name: Tm, dtype: float64

# %%
plt.figure(figsize=(9,7))

data = df['Tm']
mean, std = norm.fit(data)

# plt.hist(data, bins=25, density=True, alpha=0.7, color='blue')
sns.distplot(data, bins=25)

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x,mean,std)

plt.plot(x, p, color='k', linewidth=2)
plt.title('The mean is %.2f and std is %.2f'%(mean, std))
plt.xlabel('Min Temperature')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df['Tm'].kurtosis()
# Out:
# 0.2570615385563122

# %%
df['Tm'].skew()
# Out:
# -0.3383708207168965

# %%
plt.figure(figsize=(9,12))

sns.boxplot(y=df['Tm'])
plt.title('Min Temp BoxPlot')
plt.ylabel('Min Temperature')
# Out:
# Text(0, 0.5, 'Min Temperature')

# %% [markdown]
# We can see that Min Temperature column is affected by lots of outliers.

# %% [markdown]
# #### Atmospheric Pressure at sea level (SLP)

# %%
df.columns
# Out:
# Index(['T', 'TM', 'Tm', 'SLP', 'H', 'VV', 'V', 'VM', 'PM 2.5'], dtype='object')

# %%
df_desc.loc['SLP']
# Out:
# description    Atmospheric pressure at sea level (hPa)
# Name: SLP, dtype: object

# %%
df.SLP.unique()
# Out:
# array(['-'], dtype=object)

# %% [markdown]
# There are no values in SLP column, so we can remove this column

# %%
# Drop specified labels from rows or columns.

# Remove rows or columns by specifying label names and corresponding
# axis, or by specifying directly index or column names. When using a
# multi-index, labels on different levels can be removed by specifying
# the level.

df.drop('SLP',axis=1, inplace=True)

# %% [markdown]
# #### Average relative humidity (H)

# %%
df_desc.loc['H']
# Out:
# description    Average relative humidity (%)
# Name: H, dtype: object

# %%
df.H.unique()
# Out:
# array([59, 57, 51, 55, 46, 43, 41, 58, 47, 40, 54, 45, 37, 63, 49, 64, 68,
#        62, 29, 30, 32, 26, 34, 31, 71, 56, 39, 44, 42, 50, 53, 61, 75, 66,
#        81, 90, 86, 85, 80, 77, 70, 69, 74, 78, 87, 79, 83, 76, 73, 82, 84,
#        93, 88, 89, 72, 67, 65, 52, 48, 35, 60, 33, 38, 36, 94, 91, 27, 25,
#        92, 97], dtype=int64)

# %%
df.H.nunique()
# Out:
# 70

# %%
df.H.count()
# Out:
# 2232

# %%
df.H.isnull().sum()
# Out:
# 0

# %%
df.H.describe()
# Out:
# count    2232.000000
# mean       65.729839
# std        14.616694
# min        25.000000
# 25%        56.000000
# 50%        69.000000
# 75%        77.000000
# max        97.000000
# Name: H, dtype: float64

# %%
plt.figure(figsize=(9,7))

data = df['H']
mean, std = norm.fit(data)

sns.distplot(data, bins=25, color='g')

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)

p = norm.pdf(x, mean, std)

plt.plot(x, p, color='k', linewidth=2)
plt.title('The mean is %.2f and std is %.2f' %(mean, std))
plt.xlabel('Average Relative Humidity')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df.H.kurtosis()
# Out:
# -0.4278854194358299

# %%
df.H.skew()
# Out:
# -0.5492854866099852

# %%
plt.figure(figsize=(9,12))

sns.boxplot(y=df['H'])
plt.title('Average Relative Humidity Boxplot')
plt.ylabel('Humidity')
# Out:
# Text(0, 0.5, 'Humidity')

# %% [markdown]
# #### Average visibility (VV)

# %%
df.columns
# Out:
# Index(['T', 'TM', 'Tm', 'H', 'VV', 'V', 'VM', 'PM 2.5'], dtype='object')

# %%
df_desc.loc['VV']
# Out:
# description    Average visibility (Km)
# Name: VV, dtype: object

# %%
df.VV.unique()
# Out:
# array([6.3, 6.9, 7.7, 7.4, 5.5, 6.6, 7.6, 5.8, 4.8, 9.2, 6. , 6.8, 8.2,
#        8.5, 4. , 8. , 5.6, 5.3])

# %%
df.VV.nunique()
# Out:
# 18

# %%
df.VV.count()
# Out:
# 2232

# %%
df.VV.describe()
# Out:
# count    2232.000000
# mean        6.683333
# std         0.670363
# min         4.000000
# 25%         6.300000
# 50%         6.900000
# 75%         6.900000
# max         9.200000
# Name: VV, dtype: float64

# %%
plt.figure(figsize=(9,7))
sns.countplot(df.VV)

plt.title('Count of Average Visibility(VV)')
plt.xlabel('Visibility scale')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# Average visibility is a categorical column.

# %%
plt.figure(figsize=(9,7))

data = df['VV']

mean, std = norm.fit(data)
sns.distplot(data, bins=25, color='g')

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)

p = norm.pdf(x, mean, std)

plt.plot(x, p, color='k', linewidth=2)

plt.title('The mean is %.2f and std is %.2f' %(mean, std))
plt.xlabel('Average Visibility')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df.VV.kurtosis()
# Out:
# 4.205945899953481

# %%
df.VV.skew()
# Out:
# -0.03270737025864793

# %% [markdown]
# #### Average wind speed (V)

# %%
df.columns
# Out:
# Index(['T', 'TM', 'Tm', 'H', 'VV', 'V', 'VM', 'PM 2.5'], dtype='object')

# %%
df_desc.loc['V']
# Out:
# description    Average wind speed (Km/h)
# Name: V, dtype: object

# %%
df.V.unique()
# Out:
# array([ 4.3,  3.3,  2.8,  3.7,  3.5,  1.9,  3.1,  2.2,  2.4,  4.8,  5.2,
#         3.9,  5.9,  2. ,  5. ,  0.9,  4.6,  1.5,  3. ,  6.5,  4.4,  5.6,
#         8. ,  6.3,  6.1,  8.7,  8.1, 12.4, 11.3,  9.8,  9.6,  8.5,  7.2,
#         8.9,  5.7,  6.9,  6.7,  5.4, 11.7,  4.1,  7.6,  2.6,  1.3,  0. ,
#         1.1,  0.4,  0.7,  7.4,  9.4,  9.3,  9.1, 11.1,  7.8,  7. ,  0.6,
#         0.2, 12. ,  8.3, 12.2, 10.9])

# %%
df.V.nunique()
# Out:
# 60

# %%
df.V.count()
# Out:
# 2232

# %%
df.V.describe()
# Out:
# count    2232.000000
# mean        3.833737
# std         2.295326
# min         0.000000
# 25%         2.200000
# 50%         3.500000
# 75%         5.200000
# max        12.400000
# Name: V, dtype: float64

# %%
plt.figure(figsize=(9,7))

data = df.V
mean, std = norm.fit(data)

sns.distplot(data, bins=25, color='y')

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)

p = norm.pdf(x, mean, std)

plt.plot(x, p, color='k', linewidth=2)
plt.title('The mean is %.2f and std is %.2f' %(mean, std))
plt.xlabel('Average wind speed')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df.V.kurtosis()
# Out:
# 0.5544176244500885

# %%
df.V.skew()
# Out:
# 0.8195803840476379

# %%
plt.figure(figsize=(9,12))

sns.boxplot(y=df.V)

plt.title('Average wind speed BoxPlot')
plt.ylabel('Wind Speed')
# Out:
# Text(0, 0.5, 'Wind Speed')

# %% [markdown]
# #### Maximum sustained wind speed (VM)

# %%
df.columns
# Out:
# Index(['T', 'TM', 'Tm', 'H', 'VV', 'V', 'VM', 'PM 2.5'], dtype='object')

# %%
df_desc.loc['VM']
# Out:
# description    Maximum sustained wind speed (Km/h)
# Name: VM, dtype: object

# %%
df.VM.unique()
# Out:
# array(['5.4', '7.6', '3.5', '9.4', '11.1', '18.3', '14.8', '16.5', '22.2',
#        '-', '13', '1.9', '37'], dtype=object)

# %% [markdown]
# Wind speed column contain '-' value, so all the numerical values became strings. So we should remove the '-' value and replace it with np.nan and convert the whole column to float.

# %%
df.VM.nunique()
# Out:
# 13

# %%
df.VM.count()
# Out:
# 2232

# %%
df.VM.describe()
# Out:
# count     2232
# unique      13
# top        5.4
# freq       714
# Name: VM, dtype: object

# %%
# Replace values given in `to_replace` with `value`.

# Values of the Series are replaced with other values dynamically.
# This differs from updating with ``.loc`` or ``.iloc``, which require
# you to specify a location to update with some value.

df.VM.replace('-',np.nan,inplace=True)

# %%
# astype() function will cast a pandas object to a specified dtype ``dtype``.

df['VM'] = df['VM'].astype(float)

# %%
df.VM.dtype
# Out:
# dtype('float64')

# %%
df.VM.isnull().sum()
# Out:
# 21

# %%
df.VM.median()
# Out:
# 5.4

# %%
# fillna method will Fill NA/NaN values using the specified method.
# Here we are using the median value of VM column to fill the nan values.

df.VM.fillna(df.VM.median(), inplace=True)

# %%
df.VM.isnull().sum()
# Out:
# 0

# %%
df.VM.describe()
# Out:
# count    2232.000000
# mean        6.917876
# std         3.386976
# min         1.900000
# 25%         5.400000
# 50%         5.400000
# 75%         7.600000
# max        37.000000
# Name: VM, dtype: float64

# %%
plt.figure(figsize=(9,7))

data = df[df.VM.notnull()].VM
mean, std = norm.fit(data)
sns.distplot(data,bins=10, color='g')
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)

p = norm.pdf(x, mean, std)

plt.plot(x, p, color='k', linewidth=2)
plt.title('The mean is %.2f and std is %.2f' %(mean, std))
plt.xlabel('Maximum sustained wind speed')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df.VM.kurtosis()
# Out:
# 9.9395378041116

# %%
df.VM.skew()
# Out:
# 2.0990519566318384

# %%
plt.figure(figsize=(9,12))

sns.boxplot(y=df.VM)
plt.title('Maximum sustained wind speed BoxPlot')
plt.ylabel('Wind Speed')
# Out:
# Text(0, 0.5, 'Wind Speed')

# %% [markdown]
# #### Particulate Matter 2.5 (PM 2.5) (Dependant variable)

# %%
df.columns
# Out:
# Index(['T', 'TM', 'Tm', 'H', 'VV', 'V', 'VM', 'PM 2.5'], dtype='object')

# %%
df['PM 2.5'].unique()
# Out:
# array([284.796, 219.721, 182.188, 154.038, 223.208, 200.646, 285.225,
#        236.825, 276.908, 108.   , 107.625, 125.892, 181.013, 152.554,
#        152.321, 319.738, 332.708, 279.6  , 179.117,  54.792,  93.375,
#        103.   , 132.208, 127.708, 109.333,  56.458, 135.833, 122.5  ,
#         69.667,  79.833,  62.708,  21.208,   1.917,   1.833, 105.833,
#        117.583, 122.708, 111.958,  59.208,  77.208,  98.708, 123.708,
#         64.792,  52.333,  52.042, 128.333,   0.   ,  23.208,  15.167,
#         21.25 ,  81.833, 105.333, 117.75 ,  84.5  ,  46.917, 104.625,
#        110.875,  42.958, 120.875,  79.917,  94.75 , 142.5  , 133.375,
#        147.833, 158.292, 149.583, 101.5  , 106.5  , 128.125, 101.958,
#         98.417,  94.375, 110.417,  95.833,  72.25 ,  38.667,  45.375,
#         65.167,  66.083,  77.667,  70.25 ,  56.292,  77.   ,  32.958,
#         80.625,  90.708,  97.292,  50.708,  40.375,  49.417,  61.875,
# ...

# %%
df['PM 2.5'].nunique()
# Out:
# 561

# %%
df['PM 2.5'].isnull().sum()
# Out:
# 3

# %%
df['PM 2.5'].fillna(df['PM 2.5'].median(), inplace=True)

# %%
df['PM 2.5'].isnull().sum()
# Out:
# 0

# %%
df['PM 2.5'].describe()
# Out:
# count    2232.000000
# mean      108.652378
# std        83.232288
# min         0.000000
# 25%        43.562250
# 50%        81.833000
# 75%       156.062500
# max       404.500000
# Name: PM 2.5, dtype: float64

# %%
df['PM 2.5'].isnull().sum()
# Out:
# 0

# %%
plt.figure(figsize=(9,7))

data = df[df['PM 2.5'].notnull()]['PM 2.5']
mean, std = norm.fit(data)

sns.distplot(data, bins=25, color='r')

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)

p = norm.pdf(x, mean, std)

plt.plot(x, p, color='k', linewidth=2)
plt.title('The mean is %.2f and the std is %.2f' %(mean, std))
plt.xlabel('PM 2.5')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df['PM 2.5'].kurtosis()
# Out:
# 0.3584375388489751

# %%
df['PM 2.5'].skew()
# Out:
# 1.0117456990806908

# %%
plt.figure(figsize=(12,9))

sns.boxplot(y=df['PM 2.5'])
plt.title('PM 2.5 BoxPlot')
plt.ylabel('PM 2.5')
# Out:
# Text(0, 0.5, 'PM 2.5')

# %% [markdown]
# ### Removing/Fixing outliers

# %%
# def remove_outliers(df):
#     for column in df.columns:
#         Q1 = df[column].quantile(0.25)
#         Q3 = df[column].quantile(0.75)
#         IQR = Q3-Q1
#         upper_range = Q3+(1.5*IQR)
#         lower_range = Q1-(1.5*IQR)
        
#         df.loc[df[column]>upper_range,column] = df[column].median()
#         df.loc[df[column]<lower_range,column] = df[column].median()

# %%
# fig, ax = plt.subplots(nrows=len(df.columns),figsize=(9,50))
# for ind, col in enumerate(df.columns):
#     sns.boxplot(ax=ax[ind],y=df[col])
#     plt.title(f'{col} BoxPlot')
#     plt.ylabel(col)

# %%
# remove_outliers(df)

# %%
# fig, ax = plt.subplots(nrows=len(df.columns),figsize=(9,50))
# for ind, col in enumerate(df.columns):
#     sns.boxplot(ax=ax[ind],y=df[col])
#     plt.title(f'{col} BoxPlot')
#     plt.ylabel(col)

# %% [markdown]
# As I removed the outliers the cross val score decreases, so I decided to keep the outliers in all the columns.

# %% [markdown]
# ## Relationship between features

# %%
# The corr() function will Compute pairwise correlation of columns, excluding NA/null values.
# Method used is 'pearson'.

df.corr()
# Out:
#                T        TM        Tm         H        VV         V        VM  \
# T       1.000000  0.882572  0.772288 -0.481241  0.299514 -0.065034 -0.022891
# TM      0.882572  1.000000  0.512205 -0.660918  0.277216 -0.235077 -0.159919
# Tm      0.772288  0.512205  1.000000  0.100716  0.102814  0.210526  0.195307
# H      -0.481241 -0.660918  0.100716  1.000000 -0.284356  0.381746  0.298507
# VV      0.299514  0.277216  0.102814 -0.284356  1.000000  0.018456  0.007262
# V      -0.065034 -0.235077  0.210526  0.381746  0.018456  1.000000  0.788043
# VM     -0.022891 -0.159919  0.195307  0.298507  0.007262  0.788043  1.000000
# PM 2.5 -0.369398 -0.195535 -0.510770 -0.181423 -0.140953 -0.402980 -0.339945
#
#           PM 2.5
# T      -0.369398
# TM     -0.195535
# Tm     -0.510770
# H      -0.181423
# VV     -0.140953
# V      -0.402980
# VM     -0.339945
# PM 2.5  1.000000

# %%
# Here we are visualizing the correlation matrix in a heatmap.

plt.figure(figsize=(12,12))
sns.heatmap(df.corr(),annot=True,vmin=-1,square=True,cmap='viridis')

# %%
# A pairplot() will Plot pairwise relationships in a dataset.

sns.pairplot(df)

# %% [markdown]
# ### Dependent and Independent features

# %%
df.isnull().sum()
# Out:
# T         0
# TM        0
# Tm        0
# H         0
# VV        0
# V         0
# VM        0
# PM 2.5    0
# dtype: int64

# %%
# Here we are dividing our dataframe into independent and dependent variables.
# X is the independent variable and contain all columns except 'PM 2.5'.
# y is the dependent variable and contains the 'PM 2.5' column.

X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
X.head()
# Out:
#       T    TM    Tm   H   VV    V   VM
# 0  23.4  30.3  19.0  59  6.3  4.3  5.4
# 1  23.4  30.3  19.0  59  6.3  4.3  5.4
# 2  23.4  30.3  19.0  59  6.3  4.3  5.4
# 3  22.4  30.3  16.9  57  6.9  3.3  7.6
# 4  22.4  30.3  16.9  57  6.9  3.3  7.6

# %%
y.head()
# Out:
# 0    284.796
# 1    284.796
# 2    284.796
# 3    219.721
# 4    219.721
# Name: PM 2.5, dtype: float64

# %% [markdown]
# ### Feature Importance
# You can get the feature importance of each feature of your dataset by using the feature importance property of the model.
#
# Feature importance gives you a score for each feature of your data, the higher the score more important or relevant is the feature towards your output variable.
#
# Feature importance is an inbuilt class that comes with Tree Based Regressor, we will be using Extra Tree Regressor for extracting the top 10 features for the dataset.

# %%
from sklearn.ensemble import ExtraTreesRegressor
etr_model = ExtraTreesRegressor()
etr_model.fit(X,y)
# Out:
# ExtraTreesRegressor()

# %%
# The feature_importances_ will give a value which shows the importance of a feature.

etr_model.feature_importances_
# Out:
# array([0.19377026, 0.12318968, 0.2513802 , 0.11033102, 0.07563044,
#        0.16385567, 0.08184272])

# %%
# For a better understanding of the feature importance we are ploting the values.

feature_importances = pd.Series(etr_model.feature_importances_, index=X.columns)
feature_importances.nlargest(5).plot(kind='barh')

# %% [markdown]
# ### Linear Regression

# %%
# Here we are checking the distribution of our dependent variable.

plt.figure(figsize=(9,7))
sns.distplot(y, color='g')
plt.title('PM 2.5 Histogram')
plt.xlabel('PM 2.5')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# #### Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
# Here we are splitting our data into train and test sets.
# Our test size will have 33% of the total rows.

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=0)

# %% [markdown]
# #### Model Training

# %%
from sklearn.linear_model import LinearRegression

# %%
# Here we are initializing the linear regression model and fitting our training datasets.

lr_model = LinearRegression()
lr_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# These are the coefficients of our linear regression model

lr_model.coef_
# Out:
# array([-20.0657538 ,  -1.3034065 ,   2.06310253,  -2.12132606,
#         -8.46018538, -10.75434153,  -0.69808754])

# %%
# This is the y intercept.

lr_model.intercept_
# Out:
# 832.7557452359274

# %%
# R^2 score on training set.

print(f'R^2 on train set: {lr_model.score(X_train, y_train)}')
# Out:
# R^2 on train set: 0.3833974708275797

# %%
# R^2 score on test set.

print(f'R^2 on test set: {lr_model.score(X_test,y_test)}')
# Out:
# R^2 on test set: 0.40788588365032163

# %% [markdown]
# #### Cross Val Score
#
# There are different types of Cross Validation Techniques but the overall concept remains the same,
# * To partition the data into a number of subsets
# * Hold out a set at a time and train the model on remaining set
# * Test model on hold out set

# %%
from sklearn.model_selection import cross_val_score
lr_score = cross_val_score(lr_model, X, y, cv=5)

# %%
# We are calculating the mean of all 5 cross val score.

lr_score.mean()
# Out:
# 0.2607424557459167

# %% [markdown]
# #### Model Evaluation

# %%
coeff_df = pd.DataFrame(lr_model.coef_,index=X.columns, columns=['Coefficient'])
coeff_df
# Out:
#     Coefficient
# T    -20.065754
# TM    -1.303407
# Tm     2.063103
# H     -2.121326
# VV    -8.460185
# V    -10.754342
# VM    -0.698088

# %% [markdown]
# Interpreting the coefficients:
#
# - Holding all other features fixed, a 1 unit increase in T is associated with an *decrease of 20.065754 in AQI PM2.5 *.
# - Holding all other features fixed, a 1 unit increase in Tm is associated with an *increase of 2.063103 in AQI PM 2.5 *.

# %%
# In this step our model will predict the PM 2.5 on the X_test data.

prediction = lr_model.predict(X_test)

# %%
sns.distplot(y_test-prediction)

# %%
plt.scatter(y_test, prediction)

# %% [markdown]
# ## Regression Evaluation Metrics
#
#
# Here are three common evaluation metrics for regression problems:
#
# **Mean Absolute Error** (MAE) is the mean of the absolute value of the errors:
#
# $$\frac 1n\sum_{i=1}^n|y_i-\hat{y}_i|$$
#
# **Mean Squared Error** (MSE) is the mean of the squared errors:
#
# $$\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2$$
#
# **Root Mean Squared Error** (RMSE) is the square root of the mean of the squared errors:
#
# $$\sqrt{\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2}$$
#
# Comparing these metrics:
#
# - **MAE** is the easiest to understand, because it's the average error.
# - **MSE** is more popular than MAE, because MSE "punishes" larger errors, which tends to be useful in the real world.
# - **RMSE** is even more popular than MSE, because RMSE is interpretable in the "y" units.
#
# All of these are **loss functions**, because we want to minimize them.

# %%
from sklearn import metrics

# %%
print('Mean Absolue Error: ', metrics.mean_absolute_error(y_test, prediction))
print('Mean Squared Error: ', metrics.mean_squared_error(y_test, prediction))
print('Root Mean Squared Error', np.sqrt(metrics.mean_squared_error(y_test, prediction)))
# Out:
# Mean Absolue Error:  50.38939650776088
# Mean Squared Error:  4149.018132553995
# Root Mean Squared Error 64.41287241347024

# %% [markdown]
# ## Saving the model

# %%
import pickle

# We are saving the model in a pickle file.
file = open('lr_model.pkl', 'wb')

pickle.dump(lr_model, file)
